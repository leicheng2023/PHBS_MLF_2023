# %%
import pandas as pd
from multi_factors_backtest import *

# %%
#GRU_factor,GRU_patch_factor Preprocessing
def factor_Preprocessing(data,m = 10,patch = False):
    new_factor = data.copy()
    new_factor[new_factor.columns[0]] = new_factor[new_factor.columns[0]].apply(lambda x: x.lower())
    new_factor.set_index([new_factor.columns[0]],inplace=True)
    new_factor = new_factor.iloc[:,0::m]
    new_factor.columns = [pd.Timestamp(x) for x in new_factor.columns]
    new_factor = new_factor.unstack().to_frame()
    new_factor.rename_axis(index=['date','asset'],inplace=True)
    if not patch:
        new_factor.columns = ['GRU_factor']
    else:
        new_factor.columns = ['GRU_patch_factor']
    new_factor.sort_index(level=['asset', 'date'],inplace=True)
    return new_factor

# %%
# load data
df_GRU_factor = pd.read_csv('../data/saved_factor/fac1.csv')
df_GRU_factor = factor_Preprocessing(df_GRU_factor)
df_GRU_patch_factor = pd.read_csv('../data/saved_factor/fac2.csv')
df_GRU_patch_factor = factor_Preprocessing(df_GRU_patch_factor,patch = True)
df_price = pd.read_parquet('../data/backtest_data/price_23_24.par')
df_pool = pd.read_pickle('../data/backtest_data/pool_23_24.pkl')
df_benchmark = pd.read_pickle('../data/backtest_data/benchmark_000985_23_24.pkl')

# %%
df_GRU_factor
# Out:
#                      GRU_factor
# date       asset
# 2023-03-29 sh600000   -1.371356
# 2023-04-13 sh600000   -0.823966
# 2023-04-27 sh600000   -1.068712
# 2023-05-16 sh600000   -1.856871
# 2023-05-30 sh600000   -1.756791
# ...                         ...
# 2024-01-08 sz301591   -1.927985
# 2024-01-22 sz301591   -2.096848
# 2024-02-05 sz301591   -0.188311
# 2024-02-27 sz301591    0.033263
# 2024-03-12 sz301591   -0.537645
#
# [126528 rows x 1 columns]

# %%
df_GRU_patch_factor
# Out:
#                      GRU_patch_factor
# date       asset
# 2023-03-29 sh600000          0.408289
# 2023-04-13 sh600000          0.412661
# 2023-04-27 sh600000          0.184374
# 2023-05-16 sh600000          0.016240
# 2023-05-30 sh600000          0.229244
# ...                               ...
# 2024-01-08 sz301591          0.301972
# 2024-01-22 sz301591          0.366555
# 2024-02-05 sz301591          0.499894
# 2024-02-27 sz301591          0.299705
# 2024-03-12 sz301591          0.318013
#
# [126528 rows x 1 columns]

# %%
df_factor = df_GRU_factor.merge(df_GRU_patch_factor,on=['date','asset'])

# %%
# factor data
df_factor
# Out:
#                      GRU_factor  GRU_patch_factor
# date       asset
# 2023-03-29 sh600000   -1.371356          0.408289
# 2023-04-13 sh600000   -0.823966          0.412661
# 2023-04-27 sh600000   -1.068712          0.184374
# 2023-05-16 sh600000   -1.856871          0.016240
# 2023-05-30 sh600000   -1.756791          0.229244
# ...                         ...               ...
# 2024-01-08 sz301591   -1.927985          0.301972
# 2024-01-22 sz301591   -2.096848          0.366555
# 2024-02-05 sz301591   -0.188311          0.499894
# 2024-02-27 sz301591    0.033263          0.299705
# 2024-03-12 sz301591   -0.537645          0.318013
#
# [126528 rows x 2 columns]

# %%
# price data
df_price
# Out:
#                           price
# date       asset
# 2023-01-03 sh600000  107.549896
# 2023-01-04 sh600000  108.739899
# 2023-01-05 sh600000  109.334900
# 2023-01-06 sh600000  109.186203
# 2023-01-09 sh600000  109.186203
# ...                         ...
# 2024-04-03 sz301591   44.360001
# 2024-04-08 sz301591   41.810001
# 2024-04-09 sz301591   43.180000
# 2024-04-10 sz301591   42.750000
# 2024-04-11 sz301591   43.160000
#
# [1543812 rows x 1 columns]

# %%
# benchmark 000985
df_benchmark
# Out:
# {'000985':                  000985
#  date
#  2011-01-04  3715.530029
#  2011-01-05  3709.429932
#  2011-01-06  3691.120117
#  2011-01-07  3687.250000
#  2011-01-10  3605.540039
#  ...                 ...
#  2024-04-03  4353.738770
#  2024-04-08  4293.420898
#  2024-04-09  4315.467285
#  2024-04-10  4258.492188
#  2024-04-11  4265.379395
#
#  [3224 rows x 1 columns]}

# %%
df_benchmark['000985']
# Out:
#                  000985
# date
# 2011-01-04  3715.530029
# 2011-01-05  3709.429932
# 2011-01-06  3691.120117
# 2011-01-07  3687.250000
# 2011-01-10  3605.540039
# ...                 ...
# 2024-04-03  4353.738770
# 2024-04-08  4293.420898
# 2024-04-09  4315.467285
# 2024-04-10  4258.492188
# 2024-04-11  4265.379395
#
# [3224 rows x 1 columns]

# %%
# stock pool
df_pool
# Out:
# {'000985': Empty DataFrame
#  Columns: []
#  Index: [(2023-01-03 00:00:00, sh600000), (2023-01-04 00:00:00, sh600000), (2023-01-05 00:00:00, sh600000), (2023-01-06 00:00:00, sh600000), (2023-01-09 00:00:00, sh600000), (2023-01-10 00:00:00, sh600000), (2023-01-11 00:00:00, sh600000), (2023-01-12 00:00:00, sh600000), (2023-01-13 00:00:00, sh600000), (2023-01-16 00:00:00, sh600000), (2023-01-17 00:00:00, sh600000), (2023-01-18 00:00:00, sh600000), (2023-01-19 00:00:00, sh600000), (2023-01-20 00:00:00, sh600000), (2023-01-30 00:00:00, sh600000), (2023-01-31 00:00:00, sh600000), (2023-02-01 00:00:00, sh600000), (2023-02-02 00:00:00, sh600000), (2023-02-03 00:00:00, sh600000), (2023-02-06 00:00:00, sh600000), (2023-02-07 00:00:00, sh600000), (2023-02-08 00:00:00, sh600000), (2023-02-09 00:00:00, sh600000), (2023-02-10 00:00:00, sh600000), (2023-02-13 00:00:00, sh600000), (2023-02-14 00:00:00, sh600000), (2023-02-15 00:00:00, sh600000), (2023-02-16 00:00:00, sh600000), (2023-02-17 00:00:00, sh600000), (2023-02-20 00:00:00, sh600000), (2023-02-21 00:00:00, sh600000), (2023-02-22 00:00:00, sh600000), (2023-02-23 00:00:00, sh600000), (2023-02-24 00:00:00, sh600000), (2023-02-27 00:00:00, sh600000), (2023-02-28 00:00:00, sh600000), (2023-03-01 00:00:00, sh600000), (2023-03-02 00:00:00, sh600000), (2023-03-03 00:00:00, sh600000), (2023-03-06 00:00:00, sh600000), (2023-03-07 00:00:00, sh600000), (2023-03-08 00:00:00, sh600000), (2023-03-09 00:00:00, sh600000), (2023-03-10 00:00:00, sh600000), (2023-03-13 00:00:00, sh600000), (2023-03-14 00:00:00, sh600000), (2023-03-15 00:00:00, sh600000), (2023-03-16 00:00:00, sh600000), (2023-03-17 00:00:00, sh600000), (2023-03-20 00:00:00, sh600000), (2023-03-21 00:00:00, sh600000), (2023-03-22 00:00:00, sh600000), (2023-03-23 00:00:00, sh600000), (2023-03-24 00:00:00, sh600000), (2023-03-27 00:00:00, sh600000), (2023-03-28 00:00:00, sh600000), (2023-03-29 00:00:00, sh600000), (2023-03-30 00:00:00, sh600000), (2023-03-31 00:00:00, sh600000), (2023-04-03 00:00:00, sh600000), (2023-04-04 00:00:00, sh600000), (2023-04-06 00:00:00, sh600000), (2023-04-07 00:00:00, sh600000), (2023-04-10 00:00:00, sh600000), (2023-04-11 00:00:00, sh600000), (2023-04-12 00:00:00, sh600000), (2023-04-13 00:00:00, sh600000), (2023-04-14 00:00:00, sh600000), (2023-04-17 00:00:00, sh600000), (2023-04-18 00:00:00, sh600000), (2023-04-19 00:00:00, sh600000), (2023-04-20 00:00:00, sh600000), (2023-04-21 00:00:00, sh600000), (2023-04-24 00:00:00, sh600000), (2023-04-25 00:00:00, sh600000), (2023-04-26 00:00:00, sh600000), (2023-04-27 00:00:00, sh600000), (2023-04-28 00:00:00, sh600000), (2023-05-04 00:00:00, sh600000), (2023-05-05 00:00:00, sh600000), (2023-05-08 00:00:00, sh600000), (2023-05-09 00:00:00, sh600000), (2023-05-10 00:00:00, sh600000), (2023-05-11 00:00:00, sh600000), (2023-05-12 00:00:00, sh600000), (2023-05-15 00:00:00, sh600000), (2023-05-16 00:00:00, sh600000), (2023-05-17 00:00:00, sh600000), (2023-05-18 00:00:00, sh600000), (2023-05-19 00:00:00, sh600000), (2023-05-22 00:00:00, sh600000), (2023-05-23 00:00:00, sh600000), (2023-05-24 00:00:00, sh600000), (2023-05-25 00:00:00, sh600000), (2023-05-26 00:00:00, sh600000), (2023-05-29 00:00:00, sh600000), (2023-05-30 00:00:00, sh600000), (2023-05-31 00:00:00, sh600000), (2023-06-01 00:00:00, sh600000), (2023-06-02 00:00:00, sh600000), ...]
#
#  [1464808 rows x 0 columns]}

# %%
df_pool['000985']
# Out:
# Empty DataFrame
# Columns: []
# Index: [(2023-01-03 00:00:00, sh600000), (2023-01-04 00:00:00, sh600000), (2023-01-05 00:00:00, sh600000), (2023-01-06 00:00:00, sh600000), (2023-01-09 00:00:00, sh600000), (2023-01-10 00:00:00, sh600000), (2023-01-11 00:00:00, sh600000), (2023-01-12 00:00:00, sh600000), (2023-01-13 00:00:00, sh600000), (2023-01-16 00:00:00, sh600000), (2023-01-17 00:00:00, sh600000), (2023-01-18 00:00:00, sh600000), (2023-01-19 00:00:00, sh600000), (2023-01-20 00:00:00, sh600000), (2023-01-30 00:00:00, sh600000), (2023-01-31 00:00:00, sh600000), (2023-02-01 00:00:00, sh600000), (2023-02-02 00:00:00, sh600000), (2023-02-03 00:00:00, sh600000), (2023-02-06 00:00:00, sh600000), (2023-02-07 00:00:00, sh600000), (2023-02-08 00:00:00, sh600000), (2023-02-09 00:00:00, sh600000), (2023-02-10 00:00:00, sh600000), (2023-02-13 00:00:00, sh600000), (2023-02-14 00:00:00, sh600000), (2023-02-15 00:00:00, sh600000), (2023-02-16 00:00:00, sh600000), (2023-02-17 00:00:00, sh600000), (2023-02-20 00:00:00, sh600000), (2023-02-21 00:00:00, sh600000), (2023-02-22 00:00:00, sh600000), (2023-02-23 00:00:00, sh600000), (2023-02-24 00:00:00, sh600000), (2023-02-27 00:00:00, sh600000), (2023-02-28 00:00:00, sh600000), (2023-03-01 00:00:00, sh600000), (2023-03-02 00:00:00, sh600000), (2023-03-03 00:00:00, sh600000), (2023-03-06 00:00:00, sh600000), (2023-03-07 00:00:00, sh600000), (2023-03-08 00:00:00, sh600000), (2023-03-09 00:00:00, sh600000), (2023-03-10 00:00:00, sh600000), (2023-03-13 00:00:00, sh600000), (2023-03-14 00:00:00, sh600000), (2023-03-15 00:00:00, sh600000), (2023-03-16 00:00:00, sh600000), (2023-03-17 00:00:00, sh600000), (2023-03-20 00:00:00, sh600000), (2023-03-21 00:00:00, sh600000), (2023-03-22 00:00:00, sh600000), (2023-03-23 00:00:00, sh600000), (2023-03-24 00:00:00, sh600000), (2023-03-27 00:00:00, sh600000), (2023-03-28 00:00:00, sh600000), (2023-03-29 00:00:00, sh600000), (2023-03-30 00:00:00, sh600000), (2023-03-31 00:00:00, sh600000), (2023-04-03 00:00:00, sh600000), (2023-04-04 00:00:00, sh600000), (2023-04-06 00:00:00, sh600000), (2023-04-07 00:00:00, sh600000), (2023-04-10 00:00:00, sh600000), (2023-04-11 00:00:00, sh600000), (2023-04-12 00:00:00, sh600000), (2023-04-13 00:00:00, sh600000), (2023-04-14 00:00:00, sh600000), (2023-04-17 00:00:00, sh600000), (2023-04-18 00:00:00, sh600000), (2023-04-19 00:00:00, sh600000), (2023-04-20 00:00:00, sh600000), (2023-04-21 00:00:00, sh600000), (2023-04-24 00:00:00, sh600000), (2023-04-25 00:00:00, sh600000), (2023-04-26 00:00:00, sh600000), (2023-04-27 00:00:00, sh600000), (2023-04-28 00:00:00, sh600000), (2023-05-04 00:00:00, sh600000), (2023-05-05 00:00:00, sh600000), (2023-05-08 00:00:00, sh600000), (2023-05-09 00:00:00, sh600000), (2023-05-10 00:00:00, sh600000), (2023-05-11 00:00:00, sh600000), (2023-05-12 00:00:00, sh600000), (2023-05-15 00:00:00, sh600000), (2023-05-16 00:00:00, sh600000), (2023-05-17 00:00:00, sh600000), (2023-05-18 00:00:00, sh600000), (2023-05-19 00:00:00, sh600000), (2023-05-22 00:00:00, sh600000), (2023-05-23 00:00:00, sh600000), (2023-05-24 00:00:00, sh600000), (2023-05-25 00:00:00, sh600000), (2023-05-26 00:00:00, sh600000), (2023-05-29 00:00:00, sh600000), (2023-05-30 00:00:00, sh600000), (2023-05-31 00:00:00, sh600000), (2023-06-01 00:00:00, sh600000), (2023-06-02 00:00:00, sh600000), ...]
#
# [1464808 rows x 0 columns]

# %%
Backtest = MultiFactor_MultiPool_BackTest(
    factor_data=df_factor,
    price_data=df_price,
    benchmark_data=df_benchmark,
    pool_data=df_pool,
    start_date='20230329',
    end_date='20240410',
    is_daily_factor= False,
    direction= {'GRU_factor':1,'GRU_patch_factor':1},
    quantiles=10)
Backtest.generate_single_factor_pool_object()

# %%
Backtest.analyse_factor_autocorrelation(factor_name='GRU_factor',pool_name='000985')
# Out:
#                均值       标准差
# 1阶自相关系数  0.397711  0.076176
# 2阶自相关系数  0.205453  0.111371
# 3阶自相关系数  0.149982  0.117054
# 4阶自相关系数  0.110389  0.124640
# 5阶自相关系数  0.081422  0.092148

# %%
Backtest.analyse_factor_autocorrelation(factor_name='GRU_patch_factor',pool_name='000985')
# Out:
#                均值       标准差
# 1阶自相关系数  0.387248  0.187594
# 2阶自相关系数  0.252971  0.100317
# 3阶自相关系数  0.186559  0.104451
# 4阶自相关系数  0.140035  0.109813
# 5阶自相关系数  0.091018  0.098042

# %%
Backtest.analyse_ic(factor_name='GRU_factor',pool_name='000985')
# Out:
#                 IC均值     IC标准差      ICIR  t-statistic   p-value      IC偏度  \
# GRU_factor  0.008401  0.031259  0.268756      1.28891  0.210818  3.077204
#
#                  IC峰度      IC胜率
# GRU_factor  12.268582  0.521739

# %%
Backtest.analyse_ic(factor_name='GRU_patch_factor',pool_name='000985')
# Out:
#                       IC均值     IC标准差      ICIR  t-statistic   p-value  \
# GRU_patch_factor  0.014568  0.032363  0.450135     2.158773  0.042042
#
#                       IC偏度      IC峰度      IC胜率
# GRU_patch_factor  2.526668  9.565901  0.695652

# %%
#IC 和 accumulated IC
Backtest.plot_ic(factor_name='GRU_factor',pool_name='000985',bar_figure=True)
Backtest.plot_ic(factor_name='GRU_patch_factor',pool_name='000985',bar_figure=True)

# %%
# bar chart of annualized returns for different groups
Backtest.plot_quantile_annualized_return(factor_name='GRU_factor',pool_name='000985')
Backtest.plot_quantile_annualized_return(factor_name='GRU_patch_factor',pool_name='000985')

# %%
# detailed analysis of factor grouping returns
Backtest.analyse_return_array(factor_name='GRU_factor',pool_name='000985')
# Out:
#                      年化收益     年化波动率      夏普比率      最大回撤      卡玛比率    超额年化收益  \
# factor_quantile
# 1               -0.100464  0.235460 -0.490375 -0.335889 -0.299097 -0.002502
# 2               -0.118072  0.233633 -0.569578 -0.335079 -0.352371 -0.021944
# 3               -0.092163  0.231998 -0.461913 -0.335696 -0.274542  0.006683
# 4               -0.086427  0.230126 -0.440748 -0.317551 -0.272169  0.012810
# 5               -0.090447  0.233979 -0.450670 -0.330975 -0.273275  0.008438
# 6               -0.082170  0.239344 -0.405986 -0.324762 -0.253018  0.017999
# 7               -0.081375  0.238593 -0.403929 -0.327392 -0.248553  0.018931
# 8               -0.056102  0.232552 -0.305747 -0.306765 -0.182883  0.046259
# 9               -0.080974  0.240003 -0.399888 -0.329974 -0.245397  0.019396
# 10              -0.080131  0.243021 -0.391451 -0.321879 -0.248948  0.020277
# benchmark       -0.093992  0.162066 -0.672517 -0.290594 -0.323448       NaN
# long_short       0.023378  0.033847  0.247522 -0.015645  1.494279  0.023378
#
#                   超额年化波动率      信息比率    超额最大回撤  超额收益卡玛比率    相对基准胜率    相对整体胜率  \
# factor_quantile
# 1                0.124199 -0.020142 -0.201623 -0.012408  0.521739  0.136364
# 2                0.120144 -0.182650 -0.202410 -0.108415  0.652174  0.090909
# 3                0.117970  0.056650 -0.204515  0.032677  0.608696  0.045455
# 4                0.116918  0.109565 -0.192562  0.066525  0.695652  0.090909
# 5                0.123265  0.068457 -0.204615  0.041240  0.608696  0.136364
# 6                0.128625  0.139932 -0.206738  0.087061  0.652174  0.090909
# 7                0.126753  0.149350 -0.208511  0.090789  0.652174  0.090909
# 8                0.122800  0.376700 -0.182025  0.254133  0.652174  0.136364
# 9                0.128979  0.150380 -0.195943  0.098987  0.652174  0.136364
# 10               0.135006  0.150190 -0.202982  0.099894  0.652174  0.045455
# benchmark             NaN       NaN       NaN       NaN       NaN       NaN
# long_short       0.033847  0.690693 -0.015645  1.494279  0.565217       NaN
#
#                       盈亏比
# factor_quantile
# 1                1.022001
# 2                0.502723
# 3                0.729496
# 4                0.514563
# 5                0.763519
# 6                0.671975
# 7                0.644535
# 8                0.819918
# 9                0.682779
# 10               0.668941
# benchmark             NaN
# long_short       1.405267

# %%
Backtest.analyse_return_array(factor_name='GRU_patch_factor',pool_name='000985')
# Out:
#                      年化收益     年化波动率      夏普比率      最大回撤      卡玛比率    超额年化收益  \
# factor_quantile
# 1               -0.101550  0.235578 -0.494740 -0.326735 -0.310802 -0.003805
# 2               -0.098255  0.236679 -0.478519 -0.333066 -0.295002  0.000368
# 3               -0.109739  0.232953 -0.535466 -0.327477 -0.335103 -0.012841
# 4               -0.103885  0.234147 -0.507738 -0.332944 -0.312020 -0.006158
# 5               -0.076842  0.235766 -0.389547 -0.326325 -0.235477  0.023625
# 6               -0.100855  0.237033 -0.488771 -0.343019 -0.294020 -0.002771
# 7               -0.064000  0.237965 -0.331980 -0.318198 -0.201132  0.037875
# 8               -0.079430  0.237028 -0.398392 -0.324994 -0.244405  0.020791
# 9               -0.073814  0.234863 -0.378150 -0.320753 -0.230125  0.026983
# 10              -0.059588  0.236781 -0.315010 -0.319565 -0.186466  0.042679
# benchmark       -0.093992  0.162066 -0.672517 -0.290594 -0.323448       NaN
# long_short       0.046369  0.034426  0.911205 -0.015074  3.076143  0.046369
#
#                   超额年化波动率      信息比率    超额最大回撤  超额收益卡玛比率    相对基准胜率    相对整体胜率  \
# factor_quantile
# 1                0.125780 -0.030249 -0.206012 -0.018468  0.652174  0.136364
# 2                0.121753  0.003025 -0.195668  0.001882  0.652174  0.090909
# 3                0.120362 -0.106685 -0.191404 -0.067088  0.565217  0.045455
# 4                0.120156 -0.051248 -0.194860 -0.031601  0.652174  0.045455
# 5                0.125410  0.188385 -0.209142  0.112963  0.652174  0.181818
# 6                0.125355 -0.022109 -0.207274 -0.013371  0.608696  0.045455
# 7                0.128740  0.294198 -0.197968  0.191320  0.695652  0.136364
# 8                0.126977  0.163742 -0.206188  0.100837  0.695652  0.136364
# 9                0.123033  0.219313 -0.193173  0.139682  0.652174  0.045455
# 10               0.127491  0.334760 -0.201349  0.211965  0.652174  0.136364
# benchmark             NaN       NaN       NaN       NaN       NaN       NaN
# long_short       0.034426  1.346921 -0.015074  3.076143  0.521739       NaN
#
#                       盈亏比
# factor_quantile
# 1                0.583073
# 2                0.592703
# 3                0.809628
# 4                0.555652
# 5                0.675188
# 6                0.705193
# 7                0.595532
# 8                0.543395
# 9                0.710344
# 10               0.746219
# benchmark             NaN
# long_short       2.195452

# %%
# plot of net value 
Backtest.plot_accumulated_net_value(factor_name='GRU_factor',pool_name='000985',plot_type='long_short')
Backtest.plot_accumulated_net_value(factor_name='GRU_patch_factor',pool_name='000985',plot_type='long_short')
